# %%
# !pip3 install pandas
# !pip3 install tensorflow
# !pip3 install numpy
# !pip3 install codecarbon
# !pip3 install scikit-learn
# Out:
# Requirement already satisfied: pandas in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: tensorflow in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (3.3.3)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
# Requirement already satisfied: numpy in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
data = pd.read_csv('../../full_dataset.csv')
data.drop('date', axis=1, inplace=True)
data.head()
# Out:
#    production   latitude  longitude   vmp  imp   voc   isc  p_per_m2  p_max  \
# 0         0.8  48.575437   7.768668  27.3  7.7  33.3  8.17     143.0    210
# 1        16.9  48.575437   7.768668  27.3  7.7  33.3  8.17     143.0    210
# 2         1.4  48.575437   7.768668  27.3  7.7  33.3  8.17     143.0    210
# 3         6.6  48.575437   7.768668  27.3  7.7  33.3  8.17     143.0    210
# 4         0.3  48.575437   7.768668  27.3  7.7  33.3  8.17     143.0    210
#
#    panel_area  ...  wind_speed_10m_std  wind_speed_10m_min  wind_speed_10m_q1  \
# 0        1.72  ...            0.903114                 1.3              1.900
# 1        1.72  ...            0.969186                 0.9              2.975
# 2        1.72  ...            0.306945                 0.4              1.100
# 3        1.72  ...            0.491844                 0.4              0.800
# 4        1.72  ...            0.527737                 1.6              2.275
#
#    wind_speed_10m_q2  wind_speed_10m_q3  wind_speed_10m_max  building_id  day  \
# 0               3.00              3.450                 4.1            1    1
# 1               3.50              3.825                 4.8            1    2
# 2               1.20              1.400                 1.9            1    3
# 3               1.20              1.725                 2.1            1    4
# 4               2.85              3.100                 3.4            1    5
#
#    month  year
# 0      1  2019
# 1      1  2019
# 2      1  2019
# 3      1  2019
# 4      1  2019
#
# [5 rows x 164 columns]

# %%
data_train = data[data['building_id'] != 8]
data_test = data[data['building_id'] == 8]

data_train.shape, data_test.shape
# Out:
# ((9617, 164), (1254, 164))

# %%
target_column = 'production'

x_train = data_train.drop(target_column, axis=1)
y_train = data_train[target_column].values.reshape(-1, 1)

x_test = data_test.drop(target_column, axis=1)
y_test = data_test[target_column].values.reshape(-1, 1)

# %%
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error

# %%
x_scaler = MinMaxScaler(feature_range=(0, 1))
x_scaler.fit(x_train)

x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %%
def get_windows(x, y, window_size):
    x_windows, y_windows = [], []

    for i in range(len(x) - window_size):
        x_window = x[i:i+window_size]
        y_window = y[i:i+window_size]

        x_window = np.hstack((x_window, y_window))

        x_windows.append(x_window)
        y_windows.append(y[i+window_size])

    return np.array(x_windows), np.array(y_windows)

# %%
x_train_windows, y_train_windows = get_windows(x_train_scaled, y_train, 10)
x_test_windows, y_test_windows = get_windows(x_test_scaled, y_test, 10)

# %%
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

import tensorflow as tf
tf.random.set_seed(42)
# Out:
# 2024-05-19 02:18:00.150501: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-19 02:18:01.368348: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import time

params = [168, 'relu', 0.2, 216, 'hard_sigmoid', 0.22, 216, 'relu', 1, 'linear', 0.001, 210, 88]

model = Sequential([
    LSTM(params[0], activation=params[1], input_shape=(
        x_train_windows.shape[1:]), return_sequences=True),
    Dropout(params[2]),
    LSTM(params[3], activation=params[4], return_sequences=False),
    Dropout(params[5]),
    Dense(params[6], activation=params[7]),
    Dense(params[8], activation=params[9])
])
optimizer = Adam(learning_rate=params[10])
model.compile(optimizer=optimizer, loss='mean_absolute_error')

model.summary()

def start_training():
    start_time = time.time()
    history = model.fit(x=x_train_windows,
                        y=y_train_windows,
                        epochs=params[11],
                        batch_size=params[12],
                        validation_split=0.2,
                        verbose=1,
                        shuffle=False)
    training_duration = time.time() - start_time
    return history, training_duration
# Out:
# 2024-05-19 02:18:02.263332: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 02:18:02.302870: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 02:18:02.303091: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 02:18:02.303970: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 02:18:02.304174: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 02:18:02.304326: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 02:18:02.396633: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 02:18:02.396901: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 02:18:02.397088: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 02:18:02.397242: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 723 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5
# /home/quentin/Desktop/Optimization/.venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 168)        │       223,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 168)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 216)            │       332,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 216)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 216)            │        46,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           217 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 603,505 (2.30 MB)
#  Trainable params: 603,505 (2.30 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history, training_duration = start_training()
# Out:
# Epoch 1/210
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716077886.516545   93563 service.cc:145] XLA service 0x7819b4001f40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1716077886.516580   93563 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 2060, Compute Capability 7.5
# 2024-05-19 02:18:06.626215: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-19 02:18:07.208026: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 22/88 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.1024
# I0000 00:00:1716077893.536107   93563 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - loss: 20.3530 - val_loss: 11.3962
# Epoch 2/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 14.2741 - val_loss: 10.8061
# Epoch 3/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 13.2374 - val_loss: 10.3742
# Epoch 4/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 12.6916 - val_loss: 11.0334
# Epoch 5/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 12.6221 - val_loss: 10.4820
# Epoch 6/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 12.3517 - val_loss: 11.6895
# Epoch 7/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 12.4992 - val_loss: 10.6550
# Epoch 8/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 12.1613 - val_loss: 10.5706
# Epoch 9/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.8865 - val_loss: 10.5519
# Epoch 10/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 11.8685 - val_loss: 11.5031
# Epoch 11/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 12.4216 - val_loss: 10.3777
# Epoch 12/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.9600 - val_loss: 11.4320
# Epoch 13/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 11.9919 - val_loss: 10.7136
# Epoch 14/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 11.5920 - val_loss: 10.8645
# Epoch 15/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.5974 - val_loss: 11.1216
# Epoch 16/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.6084 - val_loss: 10.5925
# Epoch 17/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.3111 - val_loss: 10.8094
# Epoch 18/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.3619 - val_loss: 10.8021
# Epoch 19/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.1500 - val_loss: 10.6314
# Epoch 20/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.0235 - val_loss: 10.3585
# Epoch 21/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.8867 - val_loss: 10.5941
# Epoch 22/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.0009 - val_loss: 10.4531
# Epoch 23/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.8593 - val_loss: 10.4558
# Epoch 24/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.7462 - val_loss: 10.0140
# Epoch 25/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.6269 - val_loss: 10.4397
# Epoch 26/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10.5448 - val_loss: 10.7361
# Epoch 27/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.3933 - val_loss: 10.0506
# Epoch 28/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.1994 - val_loss: 10.2293
# Epoch 29/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.1509 - val_loss: 10.1851
# Epoch 30/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.2239 - val_loss: 9.9433
# Epoch 31/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.9951 - val_loss: 10.0119
# Epoch 32/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.1729 - val_loss: 9.6591
# Epoch 33/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.7593 - val_loss: 9.7443
# Epoch 34/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.7371 - val_loss: 9.7327
# Epoch 35/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.6541 - val_loss: 9.9189
# Epoch 36/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4557 - val_loss: 9.5471
# Epoch 37/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3465 - val_loss: 9.2247
# Epoch 38/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3906 - val_loss: 9.5001
# Epoch 39/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3989 - val_loss: 10.1265
# Epoch 40/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.2314 - val_loss: 9.6480
# Epoch 41/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.2853 - val_loss: 9.3161
# Epoch 42/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.0414 - val_loss: 9.0962
# Epoch 43/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.1638 - val_loss: 9.4340
# Epoch 44/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.8489 - val_loss: 9.2751
# Epoch 45/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.7772 - val_loss: 9.0580
# Epoch 46/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.7524 - val_loss: 8.9913
# Epoch 47/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.6408 - val_loss: 9.1140
# Epoch 48/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.5334 - val_loss: 9.2964
# Epoch 49/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.4476 - val_loss: 8.8537
# Epoch 50/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.3398 - val_loss: 8.7995
# Epoch 51/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.4001 - val_loss: 9.3320
# Epoch 52/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.4476 - val_loss: 9.4116
# Epoch 53/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.3454 - val_loss: 9.0026
# Epoch 54/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.4518 - val_loss: 8.8153
# Epoch 55/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.1267 - val_loss: 8.6549
# Epoch 56/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.0994 - val_loss: 8.7778
# Epoch 57/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.2236 - val_loss: 8.8796
# Epoch 58/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.1423 - val_loss: 8.3938
# Epoch 59/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.0233 - val_loss: 8.9238
# Epoch 60/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7980 - val_loss: 8.6805
# Epoch 61/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.9156 - val_loss: 9.2815
# Epoch 62/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.9248 - val_loss: 8.7941
# Epoch 63/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7175 - val_loss: 8.7923
# Epoch 64/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7105 - val_loss: 8.8256
# Epoch 65/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.4139 - val_loss: 8.7252
# Epoch 66/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.6743 - val_loss: 8.4574
# Epoch 67/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.6928 - val_loss: 8.3327
# Epoch 68/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7419 - val_loss: 8.6603
# Epoch 69/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.3609 - val_loss: 8.2873
# Epoch 70/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.4504 - val_loss: 8.3557
# Epoch 71/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.1710 - val_loss: 8.1558
# Epoch 72/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.2518 - val_loss: 8.0451
# Epoch 73/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.9580 - val_loss: 8.1319
# Epoch 74/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.1350 - val_loss: 8.4269
# Epoch 75/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.0248 - val_loss: 8.3266
# Epoch 76/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.8290 - val_loss: 8.2431
# Epoch 77/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.8804 - val_loss: 8.2205
# Epoch 78/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.0330 - val_loss: 8.1043
# Epoch 79/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.8730 - val_loss: 8.1424
# Epoch 80/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7573 - val_loss: 8.2136
# Epoch 81/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7995 - val_loss: 7.9938
# Epoch 82/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.8719 - val_loss: 8.1312
# Epoch 83/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7647 - val_loss: 8.1500
# Epoch 84/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6748 - val_loss: 8.2445
# Epoch 85/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6834 - val_loss: 7.6429
# Epoch 86/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6655 - val_loss: 7.5704
# Epoch 87/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.5913 - val_loss: 7.9777
# Epoch 88/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4814 - val_loss: 7.8884
# Epoch 89/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.5801 - val_loss: 7.6997
# Epoch 90/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6105 - val_loss: 7.7400
# Epoch 91/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.5298 - val_loss: 7.8935
# Epoch 92/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4477 - val_loss: 8.0045
# Epoch 93/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.5359 - val_loss: 7.8732
# Epoch 94/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.3777 - val_loss: 7.9751
# Epoch 95/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.5692 - val_loss: 8.0053
# Epoch 96/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2949 - val_loss: 8.3742
# Epoch 97/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4680 - val_loss: 8.0935
# Epoch 98/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.3514 - val_loss: 8.1078
# Epoch 99/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.1860 - val_loss: 8.0902
# Epoch 100/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.1907 - val_loss: 8.0520
# Epoch 101/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.1717 - val_loss: 7.5371
# Epoch 102/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8847 - val_loss: 7.8132
# Epoch 103/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.9884 - val_loss: 7.6784
# Epoch 104/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0255 - val_loss: 7.6384
# Epoch 105/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8111 - val_loss: 7.4629
# Epoch 106/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8385 - val_loss: 7.4580
# Epoch 107/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5
210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.7655 - val_loss: 7.0640
# Epoch 174/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.6101 - val_loss: 7.1818
# Epoch 175/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5314 - val_loss: 7.0200
# Epoch 176/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5171 - val_loss: 6.9463
# Epoch 177/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5667 - val_loss: 7.2222
# Epoch 178/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5702 - val_loss: 7.0682
# Epoch 179/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5248 - val_loss: 7.0586
# Epoch 180/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4446 - val_loss: 7.0041
# Epoch 181/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.6176 - val_loss: 7.0086
# Epoch 182/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.6855 - val_loss: 7.0707
# Epoch 183/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.7412 - val_loss: 7.1279
# Epoch 184/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.6460 - val_loss: 7.3296
# Epoch 185/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.6253 - val_loss: 6.9511
# Epoch 186/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5106 - val_loss: 7.1120
# Epoch 187/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5476 - val_loss: 7.1406
# Epoch 188/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4199 - val_loss: 6.9592
# Epoch 189/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3312 - val_loss: 7.1465
# Epoch 190/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.5093 - val_loss: 7.2256
# Epoch 191/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5952 - val_loss: 7.3431
# Epoch 192/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3207 - val_loss: 6.9263
# Epoch 193/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4471 - val_loss: 7.3874
# Epoch 194/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3598 - val_loss: 7.0291
# Epoch 195/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.4376 - val_loss: 7.6175
# Epoch 196/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4835 - val_loss: 7.0855
# Epoch 197/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9408 - val_loss: 7.4892
# Epoch 198/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.8957 - val_loss: 7.2320
# Epoch 199/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.4924 - val_loss: 7.4602
# Epoch 200/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3351 - val_loss: 7.1694
# Epoch 201/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4192 - val_loss: 7.2487
# Epoch 202/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3790 - val_loss: 7.1426
# Epoch 203/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.3832 - val_loss: 7.1004
# Epoch 204/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3745 - val_loss: 7.1136
# Epoch 205/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3959 - val_loss: 7.0967
# Epoch 206/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4105 - val_loss: 7.1192
# Epoch 207/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.2929 - val_loss: 7.0542
# Epoch 208/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.3632 - val_loss: 7.2449
# Epoch 209/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.2261 - val_loss: 7.4291
# Epoch 210/210
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.2652 - val_loss: 7.0543

# %%
import matplotlib.pyplot as plt

start = 10
plt.plot(history.history['loss'][start:], label='train')
plt.plot(history.history['val_loss'][start:], label='validation')

plt.legend()
plt.show()

# %%
def evaluate_model(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)

    return {
        'mse': mse,
        'r2': r2,
        'mae': mae,
        'mape': mape,
    }

# %%
y_pred_train = model.predict(x_train_windows)
y_pred_test = model.predict(x_test_windows)

print(evaluate_model(y_train_windows, y_pred_train))
print(evaluate_model(y_test_windows, y_pred_test))
# Out:
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'mse': 228.92610519030458, 'r2': 0.933244295419912, 'mae': 6.280669195557885, 'mape': 136935011741641.6}
# {'mse': 19.167861794862926, 'r2': 0.9377308095551262, 'mae': 2.89172148761067, 'mape': 46959802185247.695}

# %%
x_test_windows.shape
# Out:
# (1244, 10, 164)

# %%
baseline_predictions = []

for x in x_test_windows:
    baseline_predictions.append(x[-1][-1])

baseline_predictions = np.array(baseline_predictions).reshape(-1, 1)
print(evaluate_model(y_test_windows, baseline_predictions))
# Out:
# {'mse': 229.48277331189712, 'r2': 0.2544965803642203, 'mae': 10.168247588424439, 'mape': 55389931108336.664}

# %%
# model.save('../models/lstm_model.keras')

# %%
plt.figure(figsize=(20, 10))

start = 0
end = -1

plt.plot(y_test[start:end], '-^', label='true')
plt.plot(y_pred_test[start:end], '-*', label='predicted')

plt.legend()
plt.grid(True)
plt.show()
